# %% [markdown]
# ## 0 - Librairies

# %%
import os
os.environ['KERAS_BACKEND'] = 'torch'
from numpy import mean
from numpy import std
import numpy as np
import pandas as pd
from dateutil.relativedelta import relativedelta
#choose kernel (keras-env) when run on Macbook Pro 
import keras
from keras import layers
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import torch
import torch.nn
import torch.optim
import torch.profiler
import torch.utils.data
import torchvision.datasets
import torchvision.models
import torchvision.transforms as T
from datetime import datetime
import calendar
import random
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import toml
import h5py
from keramss import *
import joblib
from pathlib import Path

# %% [markdown]
# ## 1 - Config, seeding and data import

# %%
with open('./model_config.toml','r') as f:
        config = toml.load(f)
        seed = config['stat']['seed']
        t1 = config['data']['t1']
        t2 = config['data']['t2']
        sat = config['data']['sat']
        density_threshold = config['data']['density_threshold']
        name = config['model']['name']
        f_train, f_valid, f_test = config['model']['f_train'], config['model']['f_valid'], config['model']['f_test']
        shuffle = config['model']['shuffle']
        OHM = config['model']['OHM']
        epochs = config['model']['epochs']
        patience = config['model']['patience']
        data_path = config['paths']['data']
        saved_models_path = config['paths']['saved_models']
        log_path = config['paths']['logs']

        Path(f"{saved_models_path}/{name}").mkdir(parents=True, exist_ok=True)
        with open(f"{saved_models_path}/{name}/model_config.toml",'w') as fsave:
            toml.dump(config,fsave)

os.environ['PYTHONHASHSEED']=str(seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)

print(f"Using {device} device")
print(f"OHM={OHM}")
print(f"density_threshold={density_threshold}")
# Out:
# Using cuda device
# OHM=True
# density_threshold=0

# %%
#dataset = MMS_Dataset(sat,data_path,t1,t2,density_threshold,OHM=OHM)
#dataset = dataset.exclude(datetime(2015,12,8,5,0),datetime(2015,12,8,7,0)) #Exclude data from Graham & al 2017
#train_data, val_data, test_data = random_split(dataset, [0.8, 0.1, 0.1],generator=torch.Generator().manual_seed(seed))

#batch_size = int(2**(np.round(np.log2(0.25*len(train_data)/100))))
#print(f"Batch size of ~0.25% of data (rounded to closest power of 2) : {batch_size}")

# %%
from torch.utils.data import Subset

dataset = MMS_Dataset(sat,data_path,t1,t2,density_threshold,OHM=OHM)
dataset = dataset.exclude(datetime(2015,12,8,5,0),datetime(2015,12,8,7,0)) #Exclude data from Graham & al 2017

n = len(dataset)

train_end = int(0.8 * n)
val_end = int(0.9 * n)

train_data = Subset(dataset, range(0, train_end))
val_data   = Subset(dataset, range(train_end, val_end))
test_data  = Subset(dataset, range(val_end, n))

batch_size = int(2**(np.round(np.log2(0.25*len(train_data)/100))))
print(f"Batch size of ~0.25% of data (rounded to closest power of 2) : {batch_size}")

from torch.utils.data import DataLoader

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_data, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_data, batch_size=batch_size, shuffle=False)
# Out:
# Batch size of ~0.25% of data (rounded to closest power of 2) : 32768

# %%
def first_dnn(input_size,output_size,scale,device):
    model = keras.Sequential([
        layers.Dense(input_size, activation='relu'),
        layers.Dense(1024, activation='relu'),
        layers.Dense(1024, activation='relu'),
        layers.Dense(1024, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(output_size)
    ])
    model.compile(loss='mean_squared_error',
                optimizer=keras.optimizers.Adam(0.0001),metrics=[
                    MaxError(scaler=scale,device=device),
                    MSE(scaler=scale,device=device),
                    keras.metrics.R2Score(
                    class_aggregation=None, num_regressors=0, name="r2_score", dtype=None),
                    PCC()])

    return model

# %%
scale = Standard_Scaler(train_data)
torch.save(scale,f'{saved_models_path}/{name}/scale.keras')
#torch.load()
X_train, y_train = scale.transform(dataset=train_data)
X_val  , y_val   = scale.transform(dataset=val_data)
X_test , y_test  = scale.transform(dataset=test_data)

scale.to(device)
X_train, y_train = X_train.to(device) , y_train.to(device)

print(device)
# Out:
# cuda

# %%
model = first_dnn(np.shape(X_train)[1]-3,3,scale,device)

#model.summary()

# %%
class LossAndErrorPrintingCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(
            "The average loss for epoch {} is {:7.2f} "
            "and mean absolute error is {:7.2f}.".format(
                epoch, logs["loss"], logs['r2_score'], logs['MSE'], logs['max_error']
            )
        )

# %%
class TorchTensorBoard(keras.callbacks.Callback):
    '''
    https://github.com/keras-team/keras/issues/19121
    '''
    def __init__(self, path):
        self._path = path
        self._writers = {}

    def writer(self, writer):
        if writer not in self._writers:
            import torch.utils.tensorboard
            self._writers[writer] = torch.utils.tensorboard.SummaryWriter(os.path.join(self._path, writer))
        return self._writers[writer]

    def add_logs(self, writer, logs, step):
        for key, value in logs.items():
            self.writer(writer).add_scalar(key, value, step)

    def on_epoch_end(self, epoch, logs=None):
        if logs:
            dic = {}
            for k, v in logs.items():
                if not k.startswith("val_"):
                    #print('k :',k)
                    #print('v :',v)
                    if type(v) != float and len(v)==3:
                        dic.update({k+'/x':v[0]})
                        dic.update({k+'/y':v[1]})
                        dic.update({k+'/z':v[2]})
                        dic.update({k+'/global':v.square().mean().sqrt()})
                    else:
                        dic.update({k: v})
                self.add_logs("train",dic, epoch + 1)
            if isinstance(getattr(self.model, "optimizer", None), keras.optimizers.Optimizer):
                #print(self.model.optimizer.learning_rate)
                self.add_logs("train", {"learning_rate": self.model.optimizer.learning_rate.numpy()}, epoch + 1)
            dic = {}
            for k, v in logs.items():
                if k.startswith("val_"):
                    #print('k :',k)
                    #print('v :',v)
                    if type(v) != float and len(v)==3:
                        dic.update({k[4:]+'/x':v[0]})
                        dic.update({k[4:]+'/y':v[1]})
                        dic.update({k[4:]+'/z':v[2]})
                        dic.update({k[4:]+'/global':v.square().mean().sqrt()})
                    else:
                        dic.update({k[4:]: v})
                self.add_logs("val", dic, epoch + 1)

# %%
# checkpoint
log_dir = f'{log_path}/{name}_' + datetime.now().strftime("%Y%m%d-%H%M%S")
filepath= f'{saved_models_path}/{name}/_weights.best.keras'
checkpoint = keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True)
earlystopping_callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience)

# %%
my_callbacks = [earlystopping_callback, checkpoint, TorchTensorBoard(log_dir)]#, LossAndErrorPrintingCallback()]
if True:
    model.fit(X_train, y_train, epochs=epochs, 
            validation_data=(X_val, y_val), verbose=2,
            callbacks=my_callbacks,batch_size=batch_size)
    model.save_weights(f'{saved_models_path}/{name}/model.weights.h5', overwrite=True)
    model.save(f'{saved_models_path}/{name}/model.keras')
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 0.29322, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 140ms/step - MSE: 3.5912 - PCC: 0.8498 - loss: 0.3915 - max_error: 23.9625 - r2_score: 0.6083 - val_MSE: 0.9483 - val_PCC: 0.8943 - val_loss: 0.2932 - val_max_error: 4.3595 - val_r2_score: 0.7063
# Epoch 2/300
#
# Epoch 2: val_loss did not improve from 0.29322
# 358/358 - 50s - 140ms/step - MSE: 3.1795 - PCC: 0.8687 - loss: 0.2941 - max_error: 17.4210 - r2_score: 0.7058 - val_MSE: 0.5255 - val_PCC: 0.9133 - val_loss: 0.2962 - val_max_error: 3.5833 - val_r2_score: 0.7032
# Epoch 3/300
#
# Epoch 3: val_loss improved from 0.29322 to 0.27059, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 139ms/step - MSE: 3.2978 - PCC: 0.8601 - loss: 0.2762 - max_error: 17.1487 - r2_score: 0.7238 - val_MSE: 1.1217 - val_PCC: 0.9219 - val_loss: 0.2706 - val_max_error: 3.0534 - val_r2_score: 0.7290
# Epoch 4/300
#
# Epoch 4: val_loss improved from 0.27059 to 0.23292, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 2.6148 - PCC: 0.8874 - loss: 0.2481 - max_error: 21.1742 - r2_score: 0.7518 - val_MSE: 0.3573 - val_PCC: 0.9262 - val_loss: 0.2329 - val_max_error: 2.8084 - val_r2_score: 0.7667
# Epoch 5/300
#
# Epoch 5: val_loss did not improve from 0.23292
# 358/358 - 49s - 136ms/step - MSE: 2.6518 - PCC: 0.8938 - loss: 0.2343 - max_error: 15.5620 - r2_score: 0.7656 - val_MSE: 0.3146 - val_PCC: 0.9267 - val_loss: 0.2457 - val_max_error: 2.3376 - val_r2_score: 0.7538
# Epoch 6/300
#
# Epoch 6: val_loss improved from 0.23292 to 0.21169, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 2.8378 - PCC: 0.8836 - loss: 0.2268 - max_error: 26.0984 - r2_score: 0.7732 - val_MSE: 0.3218 - val_PCC: 0.9275 - val_loss: 0.2117 - val_max_error: 2.1618 - val_r2_score: 0.7879
# Epoch 7/300
#
# Epoch 7: val_loss improved from 0.21169 to 0.20715, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 2.5995 - PCC: 0.8910 - loss: 0.2172 - max_error: 16.8313 - r2_score: 0.7828 - val_MSE: 0.3492 - val_PCC: 0.9229 - val_loss: 0.2071 - val_max_error: 2.0930 - val_r2_score: 0.7925
# Epoch 8/300
#
# Epoch 8: val_loss did not improve from 0.20715
# 358/358 - 48s - 135ms/step - MSE: 2.5581 - PCC: 0.8913 - loss: 0.2147 - max_error: 27.8167 - r2_score: 0.7853 - val_MSE: 0.3292 - val_PCC: 0.9269 - val_loss: 0.2316 - val_max_error: 2.0810 - val_r2_score: 0.7680
# Epoch 9/300
#
# Epoch 9: val_loss improved from 0.20715 to 0.20214, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 140ms/step - MSE: 2.4441 - PCC: 0.8938 - loss: 0.2074 - max_error: 16.5321 - r2_score: 0.7925 - val_MSE: 0.3346 - val_PCC: 0.9260 - val_loss: 0.2021 - val_max_error: 2.0899 - val_r2_score: 0.7975
# Epoch 10/300
#
# Epoch 10: val_loss improved from 0.20214 to 0.19718, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 2.4181 - PCC: 0.8968 - loss: 0.2005 - max_error: 16.2207 - r2_score: 0.7995 - val_MSE: 0.3356 - val_PCC: 0.9255 - val_loss: 0.1972 - val_max_error: 2.1793 - val_r2_score: 0.8025
# Epoch 11/300
#
# Epoch 11: val_loss improved from 0.19718 to 0.18905, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 2.3145 - PCC: 0.8975 - loss: 0.1981 - max_error: 21.5989 - r2_score: 0.8019 - val_MSE: 0.3347 - val_PCC: 0.9253 - val_loss: 0.1890 - val_max_error: 2.1898 - val_r2_score: 0.8106
# Epoch 12/300
#
# Epoch 12: val_loss improved from 0.18905 to 0.18589, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 2.4072 - PCC: 0.9001 - loss: 0.1903 - max_error: 25.4378 - r2_score: 0.8097 - val_MSE: 0.3266 - val_PCC: 0.9261 - val_loss: 0.1859 - val_max_error: 2.2725 - val_r2_score: 0.8138
# Epoch 13/300
#
# Epoch 13: val_loss improved from 0.18589 to 0.18311, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 2.5863 - PCC: 0.8946 - loss: 0.1872 - max_error: 24.7555 - r2_score: 0.8129 - val_MSE: 0.3510 - val_PCC: 0.9238 - val_loss: 0.1831 - val_max_error: 2.2679 - val_r2_score: 0.8166
# Epoch 14/300
#
# Epoch 14: val_loss improved from 0.18311 to 0.18059, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 2.0940 - PCC: 0.9103 - loss: 0.1848 - max_error: 15.9869 - r2_score: 0.8152 - val_MSE: 0.3140 - val_PCC: 0.9274 - val_loss: 0.1806 - val_max_error: 2.2663 - val_r2_score: 0.8191
# Epoch 15/300
#
# Epoch 15: val_loss improved from 0.18059 to 0.17886, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 138ms/step - MSE: 2.1175 - PCC: 0.9135 - loss: 0.1834 - max_error: 13.4950 - r2_score: 0.8166 - val_MSE: 0.3636 - val_PCC: 0.9256 - val_loss: 0.1789 - val_max_error: 2.2136 - val_r2_score: 0.8208
# Epoch 16/300
#
# Epoch 16: val_loss improved from 0.17886 to 0.17417, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 2.2784 - PCC: 0.9057 - loss: 0.1789 - max_error: 17.3126 - r2_score: 0.8211 - val_MSE: 0.2918 - val_PCC: 0.9316 - val_loss: 0.1742 - val_max_error: 2.2961 - val_r2_score: 0.8255
# Epoch 17/300
#
# Epoch 17: val_loss improved from 0.17417 to 0.17232, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 2.1772 - PCC: 0.9060 - loss: 0.1754 - max_error: 17.5696 - r2_score: 0.8246 - val_MSE: 0.3004 - val_PCC: 0.9330 - val_loss: 0.1723 - val_max_error: 2.3507 - val_r2_score: 0.8274
# Epoch 18/300
#
# Epoch 18: val_loss improved from 0.17232 to 0.16894, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 2.0244 - PCC: 0.9132 - loss: 0.1720 - max_error: 19.4861 - r2_score: 0.8280 - val_MSE: 0.2715 - val_PCC: 0.9364 - val_loss: 0.1689 - val_max_error: 2.3153 - val_r2_score: 0.8307
# Epoch 19/300
#
# Epoch 19: val_loss improved from 0.16894 to 0.16590, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 2.2928 - PCC: 0.9085 - loss: 0.1695 - max_error: 28.0051 - r2_score: 0.8306 - val_MSE: 0.2584 - val_PCC: 0.9381 - val_loss: 0.1659 - val_max_error: 2.2838 - val_r2_score: 0.8338
# Epoch 20/300
#
# Epoch 20: val_loss improved from 0.16590 to 0.16315, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 139ms/step - MSE: 2.2260 - PCC: 0.9028 - loss: 0.1672 - max_error: 19.2887 - r2_score: 0.8328 - val_MSE: 0.2593 - val_PCC: 0.9379 - val_loss: 0.1631 - val_max_error: 2.3361 - val_r2_score: 0.8366
# Epoch 21/300
#
# Epoch 21: val_loss improved from 0.16315 to 0.16041, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 51s - 142ms/step - MSE: 2.0038 - PCC: 0.9135 - loss: 0.1641 - max_error: 14.7638 - r2_score: 0.8359 - val_MSE: 0.2454 - val_PCC: 0.9399 - val_loss: 0.1604 - val_max_error: 2.2841 - val_r2_score: 0.8393
# Epoch 22/300
#
# Epoch 22: val_loss improved from 0.16041 to 0.15853, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 138ms/step - MSE: 2.0250 - PCC: 0.9132 - loss: 0.1616 - max_error: 19.2526 - r2_score: 0.8384 - val_MSE: 0.2491 - val_PCC: 0.9406 - val_loss: 0.1585 - val_max_error: 2.3334 - val_r2_score: 0.8412
# Epoch 23/300
#
# Epoch 23: val_loss improved from 0.15853 to 0.15642, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.9125 - PCC: 0.9154 - loss: 0.1592 - max_error: 17.6225 - r2_score: 0.8408 - val_MSE: 0.2568 - val_PCC: 0.9404 - val_loss: 0.1564 - val_max_error: 2.1616 - val_r2_score: 0.8433
# Epoch 24/300
#
# Epoch 24: val_loss improved from 0.15642 to 0.15477, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 141ms/step - MSE: 1.9746 - PCC: 0.9163 - loss: 0.1573 - max_error: 24.2270 - r2_score: 0.8427 - val_MSE: 0.2394 - val_PCC: 0.9408 - val_loss: 0.1548 - val_max_error: 2.3588 - val_r2_score: 0.8449
# Epoch 25/300
#
# Epoch 25: val_loss improved from 0.15477 to 0.15228, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.9697 - PCC: 0.9187 - loss: 0.1553 - max_error: 24.3669 - r2_score: 0.8447 - val_MSE: 0.2409 - val_PCC: 0.9419 - val_loss: 0.1523 - val_max_error: 2.3378 - val_r2_score: 0.8474
# Epoch 26/300
#
# Epoch 26: val_loss improved from 0.15228 to 0.15072, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 140ms/step - MSE: 1.9093 - PCC: 0.9177 - loss: 0.1538 - max_error: 21.7015 - r2_score: 0.8462 - val_MSE: 0.2362 - val_PCC: 0.9424 - val_loss: 0.1507 - val_max_error: 2.2268 - val_r2_score: 0.8490
# Epoch 27/300
#
# Epoch 27: val_loss improved from 0.15072 to 0.14940, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.8404 - PCC: 0.9182 - loss: 0.1523 - max_error: 16.9090 - r2_score: 0.8477 - val_MSE: 0.2255 - val_PCC: 0.9423 - val_loss: 0.1494 - val_max_error: 2.1795 - val_r2_score: 0.8503
# Epoch 28/300
#
# Epoch 28: val_loss improved from 0.14940 to 0.14815, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.9371 - PCC: 0.9161 - loss: 0.1510 - max_error: 18.0259 - r2_score: 0.8490 - val_MSE: 0.2523 - val_PCC: 0.9415 - val_loss: 0.1482 - val_max_error: 2.3409 - val_r2_score: 0.8516
# Epoch 29/300
#
# Epoch 29: val_loss improved from 0.14815 to 0.14712, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.7903 - PCC: 0.9233 - loss: 0.1500 - max_error: 15.8101 - r2_score: 0.8500 - val_MSE: 0.2301 - val_PCC: 0.9431 - val_loss: 0.1471 - val_max_error: 2.2144 - val_r2_score: 0.8526
# Epoch 30/300
#
# Epoch 30: val_loss improved from 0.14712 to 0.14626, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 138ms/step - MSE: 1.7941 - PCC: 0.9237 - loss: 0.1484 - max_error: 18.3416 - r2_score: 0.8516 - val_MSE: 0.2946 - val_PCC: 0.9421 - val_loss: 0.1463 - val_max_error: 2.4565 - val_r2_score: 0.8535
# Epoch 31/300
#
# Epoch 31: val_loss improved from 0.14626 to 0.14539, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.7193 - PCC: 0.9268 - loss: 0.1473 - max_error: 12.6193 - r2_score: 0.8526 - val_MSE: 0.2651 - val_PCC: 0.9431 - val_loss: 0.1454 - val_max_error: 2.3885 - val_r2_score: 0.8544
# Epoch 32/300
#
# Epoch 32: val_loss improved from 0.14539 to 0.14376, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 139ms/step - MSE: 1.8431 - PCC: 0.9241 - loss: 0.1463 - max_error: 19.6093 - r2_score: 0.8538 - val_MSE: 0.2312 - val_PCC: 0.9440 - val_loss: 0.1438 - val_max_error: 2.4025 - val_r2_score: 0.8560
# Epoch 33/300
#
# Epoch 33: val_loss improved from 0.14376 to 0.14285, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.8855 - PCC: 0.9230 - loss: 0.1453 - max_error: 20.9202 - r2_score: 0.8547 - val_MSE: 0.2178 - val_PCC: 0.9438 - val_loss: 0.1428 - val_max_error: 2.2866 - val_r2_score: 0.8569
# Epoch 34/300
#
# Epoch 34: val_loss improved from 0.14285 to 0.14171, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.6504 - PCC: 0.9283 - loss: 0.1443 - max_error: 12.8334 - r2_score: 0.8557 - val_MSE: 0.2671 - val_PCC: 0.9422 - val_loss: 0.1417 - val_max_error: 2.1235 - val_r2_score: 0.8580
# Epoch 35/300
#
# Epoch 35: val_loss improved from 0.14171 to 0.14094, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.9286 - PCC: 0.9190 - loss: 0.1434 - max_error: 21.3618 - r2_score: 0.8567 - val_MSE: 0.2490 - val_PCC: 0.9454 - val_loss: 0.1409 - val_max_error: 2.3666 - val_r2_score: 0.8588
# Epoch 36/300
#
# Epoch 36: val_loss improved from 0.14094 to 0.14005, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 138ms/step - MSE: 1.7520 - PCC: 0.9293 - loss: 0.1425 - max_error: 15.3510 - r2_score: 0.8575 - val_MSE: 0.2884 - val_PCC: 0.9428 - val_loss: 0.1401 - val_max_error: 2.3577 - val_r2_score: 0.8597
# Epoch 37/300
#
# Epoch 37: val_loss improved from 0.14005 to 0.13990, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.7611 - PCC: 0.9264 - loss: 0.1418 - max_error: 18.4929 - r2_score: 0.8582 - val_MSE: 0.2343 - val_PCC: 0.9430 - val_loss: 0.1399 - val_max_error: 2.2504 - val_r2_score: 0.8598
# Epoch 38/300
#
# Epoch 38: val_loss improved from 0.13990 to 0.13901, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.7796 - PCC: 0.9233 - loss: 0.1410 - max_error: 18.4982 - r2_score: 0.8590 - val_MSE: 0.2272 - val_PCC: 0.9441 - val_loss: 0.1390 - val_max_error: 2.3196 - val_r2_score: 0.8607
# Epoch 39/300
#
# Epoch 39: val_loss improved from 0.13901 to 0.13812, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 51s - 142ms/step - MSE: 1.6376 - PCC: 0.9291 - loss: 0.1403 - max_error: 12.6149 - r2_score: 0.8597 - val_MSE: 0.2512 - val_PCC: 0.9436 - val_loss: 0.1381 - val_max_error: 2.3564 - val_r2_score: 0.8616
# Epoch 40/300
#
# Epoch 40: val_loss improved from 0.13812 to 0.13698, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.6415 - PCC: 0.9295 - loss: 0.1397 - max_error: 18.2605 - r2_score: 0.8603 - val_MSE: 0.2104 - val_PCC: 0.9456 - val_loss: 0.1370 - val_max_error: 2.1744 - val_r2_score: 0.8628
# Epoch 41/300
#
# Epoch 41: val_loss did not improve from 0.13698
# 358/358 - 49s - 138ms/step - MSE: 1.7470 - PCC: 0.9275 - loss: 0.1389 - max_error: 22.1083 - r2_score: 0.8611 - val_MSE: 0.3261 - val_PCC: 0.9429 - val_loss: 0.1371 - val_max_error: 1.7707 - val_r2_score: 0.8627
# Epoch 42/300
#
# Epoch 42: val_loss improved from 0.13698 to 0.13564, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.6861 - PCC: 0.9290 - loss: 0.1383 - max_error: 19.5468 - r2_score: 0.8617 - val_MSE: 0.2205 - val_PCC: 0.9423 - val_loss: 0.1356 - val_max_error: 2.2642 - val_r2_score: 0.8641
# Epoch 43/300
#
# Epoch 43: val_loss improved from 0.13564 to 0.13543, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 139ms/step - MSE: 1.6100 - PCC: 0.9301 - loss: 0.1376 - max_error: 12.6588 - r2_score: 0.8624 - val_MSE: 0.2191 - val_PCC: 0.9434 - val_loss: 0.1354 - val_max_error: 2.1975 - val_r2_score: 0.8643
# Epoch 44/300
#
# Epoch 44: val_loss improved from 0.13543 to 0.13472, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.6938 - PCC: 0.9272 - loss: 0.1371 - max_error: 19.0003 - r2_score: 0.8629 - val_MSE: 0.2207 - val_PCC: 0.9446 - val_loss: 0.1347 - val_max_error: 2.0641 - val_r2_score: 0.8650
# Epoch 45/300
#
# Epoch 45: val_loss improved from 0.13472 to 0.13377, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.6678 - PCC: 0.9316 - loss: 0.1365 - max_error: 11.1381 - r2_score: 0.8635 - val_MSE: 0.2277 - val_PCC: 0.9434 - val_loss: 0.1338 - val_max_error: 2.1691 - val_r2_score: 0.8660
# Epoch 46/300
#
# Epoch 46: val_loss improved from 0.13377 to 0.13342, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.6744 - PCC: 0.9274 - loss: 0.1360 - max_error: 22.9737 - r2_score: 0.8640 - val_MSE: 0.2205 - val_PCC: 0.9442 - val_loss: 0.1334 - val_max_error: 2.2061 - val_r2_score: 0.8663
# Epoch 47/300
#
# Epoch 47: val_loss improved from 0.13342 to 0.13312, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.6852 - PCC: 0.9245 - loss: 0.1354 - max_error: 16.2469 - r2_score: 0.8646 - val_MSE: 0.2409 - val_PCC: 0.9457 - val_loss: 0.1331 - val_max_error: 2.0286 - val_r2_score: 0.8666
# Epoch 48/300
#
# Epoch 48: val_loss improved from 0.13312 to 0.13226, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.6810 - PCC: 0.9288 - loss: 0.1351 - max_error: 23.3710 - r2_score: 0.8649 - val_MSE: 0.2097 - val_PCC: 0.9455 - val_loss: 0.1323 - val_max_error: 2.0879 - val_r2_score: 0.8675
# Epoch 49/300
#
# Epoch 49: val_loss improved from 0.13226 to 0.13180, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 141ms/step - MSE: 1.5294 - PCC: 0.9305 - loss: 0.1345 - max_error: 13.0774 - r2_score: 0.8655 - val_MSE: 0.2223 - val_PCC: 0.9434 - val_loss: 0.1318 - val_max_error: 1.9172 - val_r2_score: 0.8680
# Epoch 50/300
#
# Epoch 50: val_loss improved from 0.13180 to 0.13143, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.6482 - PCC: 0.9291 - loss: 0.1340 - max_error: 18.1396 - r2_score: 0.8660 - val_MSE: 0.2210 - val_PCC: 0.9427 - val_loss: 0.1314 - val_max_error: 2.0840 - val_r2_score: 0.8683
# Epoch 51/300
#
# Epoch 51: val_loss did not improve from 0.13143
# 358/358 - 49s - 138ms/step - MSE: 1.5281 - PCC: 0.9321 - loss: 0.1336 - max_error: 14.1190 - r2_score: 0.8664 - val_MSE: 0.2363 - val_PCC: 0.9462 - val_loss: 0.1316 - val_max_error: 2.3352 - val_r2_score: 0.8682
# Epoch 52/300
#
# Epoch 52: val_loss improved from 0.13143 to 0.13064, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.7024 - PCC: 0.9273 - loss: 0.1332 - max_error: 21.9500 - r2_score: 0.8668 - val_MSE: 0.2238 - val_PCC: 0.9453 - val_loss: 0.1306 - val_max_error: 2.0653 - val_r2_score: 0.8691
# Epoch 53/300
#
# Epoch 53: val_loss improved from 0.13064 to 0.13049, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.5915 - PCC: 0.9321 - loss: 0.1326 - max_error: 14.5757 - r2_score: 0.8674 - val_MSE: 0.2721 - val_PCC: 0.9460 - val_loss: 0.1305 - val_max_error: 2.4681 - val_r2_score: 0.8693
# Epoch 54/300
#
# Epoch 54: val_loss improved from 0.13049 to 0.13028, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.5263 - PCC: 0.9321 - loss: 0.1323 - max_error: 17.8091 - r2_score: 0.8677 - val_MSE: 0.2302 - val_PCC: 0.9457 - val_loss: 0.1303 - val_max_error: 2.1174 - val_r2_score: 0.8695
# Epoch 55/300
#
# Epoch 55: val_loss improved from 0.13028 to 0.12946, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.5353 - PCC: 0.9340 - loss: 0.1319 - max_error: 13.6456 - r2_score: 0.8680 - val_MSE: 0.2065 - val_PCC: 0.9460 - val_loss: 0.1295 - val_max_error: 2.1726 - val_r2_score: 0.8703
# Epoch 56/300
#
# Epoch 56: val_loss improved from 0.12946 to 0.12922, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.5830 - PCC: 0.9313 - loss: 0.1315 - max_error: 16.0801 - r2_score: 0.8685 - val_MSE: 0.2337 - val_PCC: 0.9448 - val_loss: 0.1292 - val_max_error: 2.0099 - val_r2_score: 0.8706
# Epoch 57/300
#
# Epoch 57: val_loss improved from 0.12922 to 0.12864, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.4957 - PCC: 0.9342 - loss: 0.1311 - max_error: 14.3941 - r2_score: 0.8689 - val_MSE: 0.2397 - val_PCC: 0.9458 - val_loss: 0.1286 - val_max_error: 2.0841 - val_r2_score: 0.8711
# Epoch 58/300
#
# Epoch 58: val_loss improved from 0.12864 to 0.12842, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.5303 - PCC: 0.9323 - loss: 0.1308 - max_error: 10.5457 - r2_score: 0.8692 - val_MSE: 0.2041 - val_PCC: 0.9472 - val_loss: 0.1284 - val_max_error: 2.1411 - val_r2_score: 0.8713
# Epoch 59/300
#
# Epoch 59: val_loss improved from 0.12842 to 0.12807, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.6036 - PCC: 0.9330 - loss: 0.1305 - max_error: 17.3955 - r2_score: 0.8695 - val_MSE: 0.3522 - val_PCC: 0.9451 - val_loss: 0.1281 - val_max_error: 2.4527 - val_r2_score: 0.8717
# Epoch 60/300
#
# Epoch 60: val_loss improved from 0.12807 to 0.12757, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.6455 - PCC: 0.9313 - loss: 0.1302 - max_error: 14.5963 - r2_score: 0.8698 - val_MSE: 0.2165 - val_PCC: 0.9451 - val_loss: 0.1276 - val_max_error: 2.1599 - val_r2_score: 0.8722
# Epoch 61/300
#
# Epoch 61: val_loss improved from 0.12757 to 0.12716, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.4891 - PCC: 0.9338 - loss: 0.1298 - max_error: 12.7154 - r2_score: 0.8702 - val_MSE: 0.2147 - val_PCC: 0.9440 - val_loss: 0.1272 - val_max_error: 2.2556 - val_r2_score: 0.8726
# Epoch 62/300
#
# Epoch 62: val_loss improved from 0.12716 to 0.12695, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.5967 - PCC: 0.9293 - loss: 0.1295 - max_error: 15.5860 - r2_score: 0.8705 - val_MSE: 0.2289 - val_PCC: 0.9470 - val_loss: 0.1269 - val_max_error: 2.0185 - val_r2_score: 0.8728
# Epoch 63/300
#
# Epoch 63: val_loss did not improve from 0.12695
# 358/358 - 49s - 136ms/step - MSE: 1.5945 - PCC: 0.9325 - loss: 0.1294 - max_error: 16.0556 - r2_score: 0.8706 - val_MSE: 0.2115 - val_PCC: 0.9473 - val_loss: 0.1275 - val_max_error: 2.1408 - val_r2_score: 0.8722
# Epoch 64/300
#
# Epoch 64: val_loss improved from 0.12695 to 0.12617, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.5569 - PCC: 0.9290 - loss: 0.1289 - max_error: 14.6928 - r2_score: 0.8711 - val_MSE: 0.2031 - val_PCC: 0.9476 - val_loss: 0.1262 - val_max_error: 2.1609 - val_r2_score: 0.8736
# Epoch 65/300
#
# Epoch 65: val_loss did not improve from 0.12617
# 358/358 - 48s - 135ms/step - MSE: 1.7045 - PCC: 0.9310 - loss: 0.1286 - max_error: 15.1157 - r2_score: 0.8714 - val_MSE: 0.3190 - val_PCC: 0.9482 - val_loss: 0.1268 - val_max_error: 2.1387 - val_r2_score: 0.8730
# Epoch 66/300
#
# Epoch 66: val_loss improved from 0.12617 to 0.12572, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 138ms/step - MSE: 1.5576 - PCC: 0.9331 - loss: 0.1283 - max_error: 15.7335 - r2_score: 0.8717 - val_MSE: 0.2256 - val_PCC: 0.9483 - val_loss: 0.1257 - val_max_error: 2.0634 - val_r2_score: 0.8741
# Epoch 67/300
#
# Epoch 67: val_loss improved from 0.12572 to 0.12513, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.6022 - PCC: 0.9307 - loss: 0.1281 - max_error: 18.2146 - r2_score: 0.8719 - val_MSE: 0.2195 - val_PCC: 0.9479 - val_loss: 0.1251 - val_max_error: 2.0942 - val_r2_score: 0.8746
# Epoch 68/300
#
# Epoch 68: val_loss improved from 0.12513 to 0.12489, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.4472 - PCC: 0.9379 - loss: 0.1277 - max_error: 14.5891 - r2_score: 0.8723 - val_MSE: 0.2183 - val_PCC: 0.9479 - val_loss: 0.1249 - val_max_error: 2.0271 - val_r2_score: 0.8749
# Epoch 69/300
#
# Epoch 69: val_loss improved from 0.12489 to 0.12453, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.4474 - PCC: 0.9345 - loss: 0.1274 - max_error: 13.0586 - r2_score: 0.8726 - val_MSE: 0.2151 - val_PCC: 0.9478 - val_loss: 0.1245 - val_max_error: 2.3288 - val_r2_score: 0.8752
# Epoch 70/300
#
# Epoch 70: val_loss did not improve from 0.12453
# 358/358 - 49s - 138ms/step - MSE: 1.5629 - PCC: 0.9354 - loss: 0.1272 - max_error: 11.9618 - r2_score: 0.8728 - val_MSE: 0.2408 - val_PCC: 0.9485 - val_loss: 0.1246 - val_max_error: 2.0092 - val_r2_score: 0.8751
# Epoch 71/300
#
# Epoch 71: val_loss improved from 0.12453 to 0.12421, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.4848 - PCC: 0.9348 - loss: 0.1271 - max_error: 14.4950 - r2_score: 0.8729 - val_MSE: 0.1950 - val_PCC: 0.9491 - val_loss: 0.1242 - val_max_error: 2.2964 - val_r2_score: 0.8756
# Epoch 72/300
#
# Epoch 72: val_loss did not improve from 0.12421
# 358/358 - 49s - 138ms/step - MSE: 1.6293 - PCC: 0.9281 - loss: 0.1267 - max_error: 18.3628 - r2_score: 0.8733 - val_MSE: 0.2372 - val_PCC: 0.9468 - val_loss: 0.1249 - val_max_error: 2.0159 - val_r2_score: 0.8749
# Epoch 73/300
#
# Epoch 73: val_loss improved from 0.12421 to 0.12404, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.5221 - PCC: 0.9341 - loss: 0.1265 - max_error: 12.0013 - r2_score: 0.8735 - val_MSE: 0.2004 - val_PCC: 0.9477 - val_loss: 0.1240 - val_max_error: 2.2652 - val_r2_score: 0.8757
# Epoch 74/300
#
# Epoch 74: val_loss did not improve from 0.12404
# 358/358 - 48s - 135ms/step - MSE: 1.4733 - PCC: 0.9374 - loss: 0.1262 - max_error: 15.9561 - r2_score: 0.8738 - val_MSE: 0.2072 - val_PCC: 0.9471 - val_loss: 0.1242 - val_max_error: 2.2740 - val_r2_score: 0.8756
# Epoch 75/300
#
# Epoch 75: val_loss improved from 0.12404 to 0.12353, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.5617 - PCC: 0.9347 - loss: 0.1260 - max_error: 16.7347 - r2_score: 0.8740 - val_MSE: 0.2196 - val_PCC: 0.9468 - val_loss: 0.1235 - val_max_error: 2.0907 - val_r2_score: 0.8762
# Epoch 76/300
#
# Epoch 76: val_loss improved from 0.12353 to 0.12285, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.5248 - PCC: 0.9356 - loss: 0.1259 - max_error: 13.3179 - r2_score: 0.8741 - val_MSE: 0.2062 - val_PCC: 0.9492 - val_loss: 0.1228 - val_max_error: 2.1828 - val_r2_score: 0.8769
# Epoch 77/300
#
# Epoch 77: val_loss did not improve from 0.12285
# 358/358 - 48s - 135ms/step - MSE: 1.4932 - PCC: 0.9380 - loss: 0.1255 - max_error: 14.1584 - r2_score: 0.8745 - val_MSE: 0.2013 - val_PCC: 0.9473 - val_loss: 0.1233 - val_max_error: 2.1780 - val_r2_score: 0.8764
# Epoch 78/300
#
# Epoch 78: val_loss did not improve from 0.12285
# 358/358 - 49s - 136ms/step - MSE: 1.4622 - PCC: 0.9362 - loss: 0.1253 - max_error: 14.1433 - r2_score: 0.8747 - val_MSE: 0.2918 - val_PCC: 0.9488 - val_loss: 0.1235 - val_max_error: 2.0689 - val_r2_score: 0.8762
# Epoch 79/300
#
# Epoch 79: val_loss did not improve from 0.12285
# 358/358 - 49s - 136ms/step - MSE: 1.4547 - PCC: 0.9363 - loss: 0.1252 - max_error: 14.4713 - r2_score: 0.8747 - val_MSE: 0.2362 - val_PCC: 0.9459 - val_loss: 0.1230 - val_max_error: 2.2592 - val_r2_score: 0.8768
# Epoch 80/300
#
# Epoch 80: val_loss did not improve from 0.12285
# 358/358 - 48s - 135ms/step - MSE: 1.4708 - PCC: 0.9363 - loss: 0.1249 - max_error: 15.7569 - r2_score: 0.8751 - val_MSE: 0.2059 - val_PCC: 0.9465 - val_loss: 0.1229 - val_max_error: 2.1629 - val_r2_score: 0.8769
# Epoch 81/300
#
# Epoch 81: val_loss improved from 0.12285 to 0.12222, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 139ms/step - MSE: 1.4526 - PCC: 0.9384 - loss: 0.1247 - max_error: 11.7969 - r2_score: 0.8753 - val_MSE: 0.2400 - val_PCC: 0.9490 - val_loss: 0.1222 - val_max_error: 2.3469 - val_r2_score: 0.8776
# Epoch 82/300
#
# Epoch 82: val_loss did not improve from 0.12222
# 358/358 - 50s - 140ms/step - MSE: 1.4980 - PCC: 0.9374 - loss: 0.1246 - max_error: 13.4676 - r2_score: 0.8754 - val_MSE: 0.2632 - val_PCC: 0.9486 - val_loss: 0.1230 - val_max_error: 2.1402 - val_r2_score: 0.8768
# Epoch 83/300
#
# Epoch 83: val_loss did not improve from 0.12222
# 358/358 - 50s - 139ms/step - MSE: 1.5693 - PCC: 0.9326 - loss: 0.1243 - max_error: 16.9917 - r2_score: 0.8757 - val_MSE: 0.2291 - val_PCC: 0.9468 - val_loss: 0.1239 - val_max_error: 2.1178 - val_r2_score: 0.8759
# Epoch 84/300
#
# Epoch 84: val_loss improved from 0.12222 to 0.12139, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 139ms/step - MSE: 1.5662 - PCC: 0.9363 - loss: 0.1241 - max_error: 13.0403 - r2_score: 0.8759 - val_MSE: 0.1958 - val_PCC: 0.9487 - val_loss: 0.1214 - val_max_error: 2.1617 - val_r2_score: 0.8784
# Epoch 85/300
#
# Epoch 85: val_loss improved from 0.12139 to 0.12107, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 138ms/step - MSE: 1.4879 - PCC: 0.9377 - loss: 0.1239 - max_error: 13.6584 - r2_score: 0.8761 - val_MSE: 0.2289 - val_PCC: 0.9478 - val_loss: 0.1211 - val_max_error: 2.3800 - val_r2_score: 0.8787
# Epoch 86/300
#
# Epoch 86: val_loss improved from 0.12107 to 0.12093, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 138ms/step - MSE: 1.4481 - PCC: 0.9368 - loss: 0.1238 - max_error: 12.5828 - r2_score: 0.8762 - val_MSE: 0.1985 - val_PCC: 0.9481 - val_loss: 0.1209 - val_max_error: 2.2350 - val_r2_score: 0.8789
# Epoch 87/300
#
# Epoch 87: val_loss improved from 0.12093 to 0.12064, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 138ms/step - MSE: 1.4868 - PCC: 0.9385 - loss: 0.1236 - max_error: 13.9903 - r2_score: 0.8764 - val_MSE: 0.1955 - val_PCC: 0.9496 - val_loss: 0.1206 - val_max_error: 2.2655 - val_r2_score: 0.8791
# Epoch 88/300
#
# Epoch 88: val_loss did not improve from 0.12064
# 358/358 - 49s - 137ms/step - MSE: 1.5701 - PCC: 0.9294 - loss: 0.1235 - max_error: 25.4859 - r2_score: 0.8765 - val_MSE: 0.2360 - val_PCC: 0.9467 - val_loss: 0.1208 - val_max_error: 2.0197 - val_r2_score: 0.8790
# Epoch 89/300
#
# Epoch 89: val_loss did not improve from 0.12064
# 358/358 - 49s - 137ms/step - MSE: 1.4450 - PCC: 0.9369 - loss: 0.1232 - max_error: 11.2973 - r2_score: 0.8768 - val_MSE: 0.2087 - val_PCC: 0.9482 - val_loss: 0.1209 - val_max_error: 2.1623 - val_r2_score: 0.8788
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 0.12064
# 358/358 - 49s - 137ms/step - MSE: 1.5641 - PCC: 0.9342 - loss: 0.1231 - max_error: 13.5078 - r2_score: 0.8769 - val_MSE: 0.2915 - val_PCC: 0.9476 - val_loss: 0.1210 - val_max_error: 2.2235 - val_r2_score: 0.8788
# Epoch 91/300
#
# Epoch 91: val_loss improved from 0.12064 to 0.12002, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 138ms/step - MSE: 1.5473 - PCC: 0.9349 - loss: 0.1229 - max_error: 14.6941 - r2_score: 0.8771 - val_MSE: 0.2025 - val_PCC: 0.9492 - val_loss: 0.1200 - val_max_error: 2.2382 - val_r2_score: 0.8798
# Epoch 92/300
#
# Epoch 92: val_loss did not improve from 0.12002
# 358/358 - 49s - 137ms/step - MSE: 1.5098 - PCC: 0.9357 - loss: 0.1227 - max_error: 14.1176 - r2_score: 0.8774 - val_MSE: 0.2032 - val_PCC: 0.9485 - val_loss: 0.1201 - val_max_error: 2.2164 - val_r2_score: 0.8796
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 0.12002
# 358/358 - 49s - 137ms/step - MSE: 1.4893 - PCC: 0.9350 - loss: 0.1226 - max_error: 13.8518 - r2_score: 0.8774 - val_MSE: 0.2135 - val_PCC: 0.9456 - val_loss: 0.1216 - val_max_error: 2.1355 - val_r2_score: 0.8781
# Epoch 94/300
#
# Epoch 94: val_loss improved from 0.12002 to 0.11967, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 138ms/step - MSE: 1.5595 - PCC: 0.9338 - loss: 0.1224 - max_error: 17.5169 - r2_score: 0.8776 - val_MSE: 0.2240 - val_PCC: 0.9486 - val_loss: 0.1197 - val_max_error: 2.0755 - val_r2_score: 0.8801
# Epoch 95/300
#
# Epoch 95: val_loss improved from 0.11967 to 0.11964, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 138ms/step - MSE: 1.4941 - PCC: 0.9354 - loss: 0.1221 - max_error: 15.3136 - r2_score: 0.8779 - val_MSE: 0.2854 - val_PCC: 0.9493 - val_loss: 0.1196 - val_max_error: 2.0208 - val_r2_score: 0.8802
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.11964
# 358/358 - 49s - 136ms/step - MSE: 1.4858 - PCC: 0.9367 - loss: 0.1221 - max_error: 13.4643 - r2_score: 0.8779 - val_MSE: 0.2134 - val_PCC: 0.9468 - val_loss: 0.1202 - val_max_error: 2.0457 - val_r2_score: 0.8796
# Epoch 97/300
#
# Epoch 97: val_loss improved from 0.11964 to 0.11891, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 138ms/step - MSE: 1.4797 - PCC: 0.9374 - loss: 0.1219 - max_error: 21.9964 - r2_score: 0.8781 - val_MSE: 0.2280 - val_PCC: 0.9475 - val_loss: 0.1189 - val_max_error: 2.0426 - val_r2_score: 0.8809
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.11891
# 358/358 - 49s - 137ms/step - MSE: 1.5133 - PCC: 0.9352 - loss: 0.1216 - max_error: 16.7069 - r2_score: 0.8784 - val_MSE: 0.2345 - val_PCC: 0.9484 - val_loss: 0.1191 - val_max_error: 2.3330 - val_r2_score: 0.8807
# Epoch 99/300
#
# Epoch 99: val_loss did not improve from 0.11891
# 358/358 - 49s - 137ms/step - MSE: 1.5363 - PCC: 0.9368 - loss: 0.1216 - max_error: 18.0467 - r2_score: 0.8784 - val_MSE: 0.1953 - val_PCC: 0.9487 - val_loss: 0.1191 - val_max_error: 2.1332 - val_r2_score: 0.8807
# Epoch 100/300
#
# Epoch 100: val_loss improved from 0.11891 to 0.11841, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 139ms/step - MSE: 1
saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 138ms/step - MSE: 1.4405 - PCC: 0.9387 - loss: 0.1200 - max_error: 14.1917 - r2_score: 0.8800 - val_MSE: 0.2186 - val_PCC: 0.9478 - val_loss: 0.1170 - val_max_error: 2.0027 - val_r2_score: 0.8828
# Epoch 111/300
#
# Epoch 111: val_loss did not improve from 0.11697
# 358/358 - 49s - 137ms/step - MSE: 1.4188 - PCC: 0.9394 - loss: 0.1197 - max_error: 14.0490 - r2_score: 0.8803 - val_MSE: 0.2490 - val_PCC: 0.9499 - val_loss: 0.1177 - val_max_error: 2.0466 - val_r2_score: 0.8821
# Epoch 112/300
#
# Epoch 112: val_loss did not improve from 0.11697
# 358/358 - 49s - 137ms/step - MSE: 1.4484 - PCC: 0.9383 - loss: 0.1197 - max_error: 12.2871 - r2_score: 0.8803 - val_MSE: 0.1904 - val_PCC: 0.9491 - val_loss: 0.1170 - val_max_error: 2.1876 - val_r2_score: 0.8828
# Epoch 113/300
#
# Epoch 113: val_loss improved from 0.11697 to 0.11675, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 139ms/step - MSE: 1.4255 - PCC: 0.9367 - loss: 0.1196 - max_error: 12.3424 - r2_score: 0.8804 - val_MSE: 0.2323 - val_PCC: 0.9465 - val_loss: 0.1168 - val_max_error: 2.1209 - val_r2_score: 0.8830
# Epoch 114/300
#
# Epoch 114: val_loss improved from 0.11675 to 0.11643, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 138ms/step - MSE: 1.4623 - PCC: 0.9365 - loss: 0.1194 - max_error: 12.6461 - r2_score: 0.8806 - val_MSE: 0.1949 - val_PCC: 0.9491 - val_loss: 0.1164 - val_max_error: 2.0400 - val_r2_score: 0.8834
# Epoch 115/300
#
# Epoch 115: val_loss improved from 0.11643 to 0.11612, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 139ms/step - MSE: 1.3848 - PCC: 0.9422 - loss: 0.1192 - max_error: 15.0748 - r2_score: 0.8808 - val_MSE: 0.2243 - val_PCC: 0.9499 - val_loss: 0.1161 - val_max_error: 2.0908 - val_r2_score: 0.8837
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.11612
# 358/358 - 49s - 137ms/step - MSE: 1.4208 - PCC: 0.9423 - loss: 0.1191 - max_error: 15.0700 - r2_score: 0.8809 - val_MSE: 0.2445 - val_PCC: 0.9476 - val_loss: 0.1168 - val_max_error: 2.0799 - val_r2_score: 0.8830
# Epoch 117/300
#
# Epoch 117: val_loss improved from 0.11612 to 0.11594, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 51s - 142ms/step - MSE: 1.4065 - PCC: 0.9392 - loss: 0.1190 - max_error: 21.8779 - r2_score: 0.8810 - val_MSE: 0.2239 - val_PCC: 0.9483 - val_loss: 0.1159 - val_max_error: 2.0495 - val_r2_score: 0.8839
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.11594
# 358/358 - 49s - 138ms/step - MSE: 1.3596 - PCC: 0.9390 - loss: 0.1189 - max_error: 13.4145 - r2_score: 0.8811 - val_MSE: 0.2010 - val_PCC: 0.9484 - val_loss: 0.1165 - val_max_error: 2.1484 - val_r2_score: 0.8833
# Epoch 119/300
#
# Epoch 119: val_loss did not improve from 0.11594
# 358/358 - 49s - 136ms/step - MSE: 1.4494 - PCC: 0.9397 - loss: 0.1188 - max_error: 15.2346 - r2_score: 0.8812 - val_MSE: 0.2216 - val_PCC: 0.9480 - val_loss: 0.1160 - val_max_error: 2.2765 - val_r2_score: 0.8838
# Epoch 120/300
#
# Epoch 120: val_loss did not improve from 0.11594
# 358/358 - 49s - 137ms/step - MSE: 1.5405 - PCC: 0.9348 - loss: 0.1186 - max_error: 26.2341 - r2_score: 0.8814 - val_MSE: 0.2090 - val_PCC: 0.9500 - val_loss: 0.1170 - val_max_error: 2.1049 - val_r2_score: 0.8828
# Epoch 121/300
#
# Epoch 121: val_loss improved from 0.11594 to 0.11561, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.4842 - PCC: 0.9345 - loss: 0.1185 - max_error: 16.6867 - r2_score: 0.8815 - val_MSE: 0.2448 - val_PCC: 0.9504 - val_loss: 0.1156 - val_max_error: 2.2085 - val_r2_score: 0.8842
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.11561
# 358/358 - 48s - 135ms/step - MSE: 1.4175 - PCC: 0.9366 - loss: 0.1185 - max_error: 13.1955 - r2_score: 0.8815 - val_MSE: 0.2073 - val_PCC: 0.9469 - val_loss: 0.1160 - val_max_error: 2.1728 - val_r2_score: 0.8838
# Epoch 123/300
#
# Epoch 123: val_loss did not improve from 0.11561
# 358/358 - 48s - 135ms/step - MSE: 1.3772 - PCC: 0.9390 - loss: 0.1183 - max_error: 11.9624 - r2_score: 0.8817 - val_MSE: 0.2642 - val_PCC: 0.9478 - val_loss: 0.1159 - val_max_error: 2.3046 - val_r2_score: 0.8839
# Epoch 124/300
#
# Epoch 124: val_loss did not improve from 0.11561
# 358/358 - 49s - 136ms/step - MSE: 1.4283 - PCC: 0.9355 - loss: 0.1181 - max_error: 15.5879 - r2_score: 0.8819 - val_MSE: 0.2218 - val_PCC: 0.9469 - val_loss: 0.1156 - val_max_error: 1.9182 - val_r2_score: 0.8842
# Epoch 125/300
#
# Epoch 125: val_loss improved from 0.11561 to 0.11497, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.4636 - PCC: 0.9369 - loss: 0.1180 - max_error: 17.4599 - r2_score: 0.8820 - val_MSE: 0.1993 - val_PCC: 0.9495 - val_loss: 0.1150 - val_max_error: 2.2712 - val_r2_score: 0.8848
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.11497
# 358/358 - 49s - 135ms/step - MSE: 1.3982 - PCC: 0.9395 - loss: 0.1180 - max_error: 15.1451 - r2_score: 0.8820 - val_MSE: 0.1883 - val_PCC: 0.9496 - val_loss: 0.1153 - val_max_error: 2.2301 - val_r2_score: 0.8845
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.11497
# 358/358 - 48s - 135ms/step - MSE: 1.5244 - PCC: 0.9369 - loss: 0.1178 - max_error: 15.9441 - r2_score: 0.8822 - val_MSE: 0.1961 - val_PCC: 0.9487 - val_loss: 0.1154 - val_max_error: 2.2062 - val_r2_score: 0.8844
# Epoch 128/300
#
# Epoch 128: val_loss improved from 0.11497 to 0.11448, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 137ms/step - MSE: 1.4268 - PCC: 0.9393 - loss: 0.1178 - max_error: 14.8582 - r2_score: 0.8822 - val_MSE: 0.2024 - val_PCC: 0.9492 - val_loss: 0.1145 - val_max_error: 2.0720 - val_r2_score: 0.8853
# Epoch 129/300
#
# Epoch 129: val_loss improved from 0.11448 to 0.11448, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 48s - 135ms/step - MSE: 1.3650 - PCC: 0.9407 - loss: 0.1176 - max_error: 11.3115 - r2_score: 0.8824 - val_MSE: 0.2024 - val_PCC: 0.9499 - val_loss: 0.1145 - val_max_error: 2.2649 - val_r2_score: 0.8853
# Epoch 130/300
#
# Epoch 130: val_loss improved from 0.11448 to 0.11430, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 135ms/step - MSE: 1.3346 - PCC: 0.9411 - loss: 0.1175 - max_error: 14.5346 - r2_score: 0.8825 - val_MSE: 0.1995 - val_PCC: 0.9491 - val_loss: 0.1143 - val_max_error: 2.2526 - val_r2_score: 0.8855
# Epoch 131/300
#
# Epoch 131: val_loss improved from 0.11430 to 0.11412, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 141ms/step - MSE: 1.4505 - PCC: 0.9378 - loss: 0.1173 - max_error: 12.9447 - r2_score: 0.8827 - val_MSE: 0.2007 - val_PCC: 0.9502 - val_loss: 0.1141 - val_max_error: 2.2054 - val_r2_score: 0.8857
# Epoch 132/300
#
# Epoch 132: val_loss did not improve from 0.11412
# 358/358 - 48s - 135ms/step - MSE: 1.5127 - PCC: 0.9376 - loss: 0.1173 - max_error: 13.8050 - r2_score: 0.8827 - val_MSE: 0.2264 - val_PCC: 0.9492 - val_loss: 0.1147 - val_max_error: 2.2147 - val_r2_score: 0.8851
# Epoch 133/300
#
# Epoch 133: val_loss did not improve from 0.11412
# 358/358 - 49s - 136ms/step - MSE: 1.3986 - PCC: 0.9384 - loss: 0.1171 - max_error: 16.2090 - r2_score: 0.8829 - val_MSE: 0.2059 - val_PCC: 0.9502 - val_loss: 0.1144 - val_max_error: 2.0061 - val_r2_score: 0.8854
# Epoch 134/300
#
# Epoch 134: val_loss improved from 0.11412 to 0.11400, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 139ms/step - MSE: 1.4576 - PCC: 0.9405 - loss: 0.1170 - max_error: 13.8155 - r2_score: 0.8830 - val_MSE: 0.2225 - val_PCC: 0.9479 - val_loss: 0.1140 - val_max_error: 2.2369 - val_r2_score: 0.8858
# Epoch 135/300
#
# Epoch 135: val_loss improved from 0.11400 to 0.11373, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 138ms/step - MSE: 1.4667 - PCC: 0.9373 - loss: 0.1169 - max_error: 15.1401 - r2_score: 0.8831 - val_MSE: 0.2310 - val_PCC: 0.9483 - val_loss: 0.1137 - val_max_error: 2.2428 - val_r2_score: 0.8861
# Epoch 136/300
#
# Epoch 136: val_loss improved from 0.11373 to 0.11367, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 48s - 135ms/step - MSE: 1.4152 - PCC: 0.9381 - loss: 0.1168 - max_error: 10.8425 - r2_score: 0.8832 - val_MSE: 0.2042 - val_PCC: 0.9477 - val_loss: 0.1137 - val_max_error: 2.0506 - val_r2_score: 0.8861
# Epoch 137/300
#
# Epoch 137: val_loss improved from 0.11367 to 0.11345, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.5268 - PCC: 0.9357 - loss: 0.1167 - max_error: 29.3772 - r2_score: 0.8833 - val_MSE: 0.2095 - val_PCC: 0.9480 - val_loss: 0.1135 - val_max_error: 2.2075 - val_r2_score: 0.8863
# Epoch 138/300
#
# Epoch 138: val_loss did not improve from 0.11345
# 358/358 - 51s - 142ms/step - MSE: 1.4161 - PCC: 0.9386 - loss: 0.1166 - max_error: 18.7578 - r2_score: 0.8834 - val_MSE: 0.3347 - val_PCC: 0.9496 - val_loss: 0.1141 - val_max_error: 1.9074 - val_r2_score: 0.8857
# Epoch 139/300
#
# Epoch 139: val_loss did not improve from 0.11345
# Epoch 283/300
#
# Epoch 283: val_loss did not improve from 0.10286
# 358/358 - 49s - 138ms/step - MSE: 1.3002 - PCC: 0.9434 - loss: 0.1065 - max_error: 12.3351 - r2_score: 0.8935 - val_MSE: 0.2069 - val_PCC: 0.9522 - val_loss: 0.1040 - val_max_error: 2.1288 - val_r2_score: 0.8958
# Epoch 284/300
#
# Epoch 284: val_loss did not improve from 0.10286
# 358/358 - 49s - 138ms/step - MSE: 1.2715 - PCC: 0.9473 - loss: 0.1065 - max_error: 12.5150 - r2_score: 0.8935 - val_MSE: 0.1808 - val_PCC: 0.9521 - val_loss: 0.1034 - val_max_error: 2.0644 - val_r2_score: 0.8964
# Epoch 285/300
#
# Epoch 285: val_loss improved from 0.10286 to 0.10257, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 138ms/step - MSE: 1.2420 - PCC: 0.9456 - loss: 0.1063 - max_error: 13.2731 - r2_score: 0.8937 - val_MSE: 0.1935 - val_PCC: 0.9515 - val_loss: 0.1026 - val_max_error: 2.1859 - val_r2_score: 0.8973
# Epoch 286/300
#
# Epoch 286: val_loss improved from 0.10257 to 0.10248, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 139ms/step - MSE: 1.2492 - PCC: 0.9461 - loss: 0.1062 - max_error: 12.4502 - r2_score: 0.8937 - val_MSE: 0.1831 - val_PCC: 0.9516 - val_loss: 0.1025 - val_max_error: 2.1347 - val_r2_score: 0.8973
# Epoch 287/300
#
# Epoch 287: val_loss improved from 0.10248 to 0.10231, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 48s - 134ms/step - MSE: 1.3138 - PCC: 0.9440 - loss: 0.1062 - max_error: 13.6904 - r2_score: 0.8938 - val_MSE: 0.2142 - val_PCC: 0.9516 - val_loss: 0.1023 - val_max_error: 2.1932 - val_r2_score: 0.8975
# Epoch 288/300
#
# Epoch 288: val_loss did not improve from 0.10231
# 358/358 - 48s - 135ms/step - MSE: 1.2155 - PCC: 0.9495 - loss: 0.1061 - max_error: 10.3036 - r2_score: 0.8939 - val_MSE: 0.1954 - val_PCC: 0.9512 - val_loss: 0.1032 - val_max_error: 2.3324 - val_r2_score: 0.8966
# Epoch 289/300
#
# Epoch 289: val_loss did not improve from 0.10231
# 358/358 - 48s - 134ms/step - MSE: 1.3363 - PCC: 0.9428 - loss: 0.1061 - max_error: 13.1468 - r2_score: 0.8939 - val_MSE: 0.3034 - val_PCC: 0.9515 - val_loss: 0.1028 - val_max_error: 2.3056 - val_r2_score: 0.8970
# Epoch 290/300
#
# Epoch 290: val_loss improved from 0.10231 to 0.10207, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 48s - 135ms/step - MSE: 1.2753 - PCC: 0.9451 - loss: 0.1062 - max_error: 11.8008 - r2_score: 0.8938 - val_MSE: 0.2168 - val_PCC: 0.9521 - val_loss: 0.1021 - val_max_error: 2.1174 - val_r2_score: 0.8978
# Epoch 291/300
#
# Epoch 291: val_loss did not improve from 0.10207
# 358/358 - 48s - 134ms/step - MSE: 1.3482 - PCC: 0.9438 - loss: 0.1061 - max_error: 17.4298 - r2_score: 0.8939 - val_MSE: 0.2025 - val_PCC: 0.9521 - val_loss: 0.1025 - val_max_error: 1.9004 - val_r2_score: 0.8973
# Epoch 292/300
#
# Epoch 292: val_loss did not improve from 0.10207
# 358/358 - 48s - 135ms/step - MSE: 1.2964 - PCC: 0.9487 - loss: 0.1059 - max_error: 13.0385 - r2_score: 0.8941 - val_MSE: 0.1799 - val_PCC: 0.9518 - val_loss: 0.1026 - val_max_error: 2.2298 - val_r2_score: 0.8972
# Epoch 293/300
#
# Epoch 293: val_loss did not improve from 0.10207
# 358/358 - 48s - 134ms/step - MSE: 1.2664 - PCC: 0.9481 - loss: 0.1059 - max_error: 11.7914 - r2_score: 0.8941 - val_MSE: 0.1845 - val_PCC: 0.9520 - val_loss: 0.1021 - val_max_error: 2.2852 - val_r2_score: 0.8977
# Epoch 294/300
#
# Epoch 294: val_loss did not improve from 0.10207
# 358/358 - 48s - 134ms/step - MSE: 1.2473 - PCC: 0.9454 - loss: 0.1059 - max_error: 12.5391 - r2_score: 0.8941 - val_MSE: 0.1924 - val_PCC: 0.9508 - val_loss: 0.1023 - val_max_error: 2.0979 - val_r2_score: 0.8975
# Epoch 295/300
#
# Epoch 295: val_loss did not improve from 0.10207
# 358/358 - 48s - 134ms/step - MSE: 1.2599 - PCC: 0.9452 - loss: 0.1057 - max_error: 12.1673 - r2_score: 0.8943 - val_MSE: 0.1863 - val_PCC: 0.9514 - val_loss: 0.1028 - val_max_error: 2.2769 - val_r2_score: 0.8970
# Epoch 296/300
#
# Epoch 296: val_loss did not improve from 0.10207
# 358/358 - 49s - 138ms/step - MSE: 1.2421 - PCC: 0.9464 - loss: 0.1058 - max_error: 12.2611 - r2_score: 0.8942 - val_MSE: 0.1820 - val_PCC: 0.9526 - val_loss: 0.1021 - val_max_error: 2.1039 - val_r2_score: 0.8977
# Epoch 297/300
#
# Epoch 297: val_loss did not improve from 0.10207
# 358/358 - 49s - 137ms/step - MSE: 1.3081 - PCC: 0.9437 - loss: 0.1057 - max_error: 11.6374 - r2_score: 0.8944 - val_MSE: 0.2293 - val_PCC: 0.9508 - val_loss: 0.1021 - val_max_error: 1.9892 - val_r2_score: 0.8977
# Epoch 298/300
#
# Epoch 298: val_loss improved from 0.10207 to 0.10175, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 49s - 136ms/step - MSE: 1.2878 - PCC: 0.9454 - loss: 0.1057 - max_error: 14.0217 - r2_score: 0.8943 - val_MSE: 0.1870 - val_PCC: 0.9505 - val_loss: 0.1018 - val_max_error: 2.2383 - val_r2_score: 0.8981
# Epoch 299/300
#
# Epoch 299: val_loss improved from 0.10175 to 0.10164, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 50s - 138ms/step - MSE: 1.2889 - PCC: 0.9450 - loss: 0.1057 - max_error: 14.5635 - r2_score: 0.8943 - val_MSE: 0.1873 - val_PCC: 0.9510 - val_loss: 0.1016 - val_max_error: 2.1968 - val_r2_score: 0.8982
# Epoch 300/300
#
# Epoch 300: val_loss improved from 0.10164 to 0.10150, saving model to /home/esevegnes/Workspace/Saved_models/paper/_weights.best.keras
# 358/358 - 48s - 135ms/step - MSE: 1.2175 - PCC: 0.9492 - loss: 0.1056 - max_error: 10.8583 - r2_score: 0.8944 - val_MSE: 0.2295 - val_PCC: 0.9503 - val_loss: 0.1015 - val_max_error: 2.2892 - val_r2_score: 0.8983

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (32768, 13)            │           221 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (32768, 1024)          │        14,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (32768, 1024)          │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (32768, 1024)          │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (32768, 1024)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (32768, 3)             │         3,075 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,350,498 (24.23 MB)
#  Trainable params: 2,116,832 (8.08 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 4,233,666 (16.15 MB)

# %%
if False:
    new_model = keras.models.load_model(f'{saved_models_path}/{name}/model.keras')
    model.fit(X_train, y_train, epochs=1000, 
            validation_data=(X_val, y_val), verbose=2,
            callbacks=my_callbacks,batch_size=batch_size, initial_epoch=300)
    model.save_weights(f'{saved_models_path}/{name}_XL/model.weights.h5', overwrite=True)
    model.save(f'{saved_models_path}/{name}_XL/model.keras')
